# %% [markdown]
# # Цели анализа bike share

# %% [markdown]
# - Выполнить анализ данных по аренде велосипедов, выявить основные закономерности и факторы, влияющие на спрос
# - Также разработать и оценить модель прогнозирования количества аренд если открывать новую станцию
